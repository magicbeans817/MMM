# %% [markdown]
# <font size=6><b>Problem Set 2</b></font><br/>
# <font size=3>Jan Suchánek<br/>

# %%
# Necessary stuff
import inspect 
import pandas as pd
import sympy as sp
import numpy as np

import matplotlib.pyplot as plt
import math 

sp.init_printing()

# %% [markdown]
# # Problem 2 - Cobbweb model
#
# My surname is "Suchánek". Therefore according to the table, a = 4; b = 1; c = 4; d = 0.4.
# My personalized equation:

# %%
t = sp.Symbol('t', integer = True)   # time
y = sp.Function('p')                   # price
equ = sp.Eq(y(t+1),-4/10*y(t)) #my personalized equation
sol = sp.Eq(y(t), sp.rsolve(equ, y(t))) # solution of my personalized equation
display(equ, sol)
# Out:
# p(t + 1) = -0.4⋅p(t)
#            t
# p(t) = -0.4 ⋅C₀

# %% [markdown]
# ## Phase Diagram

# %%
# the gift
def path(fun, start, iter):
    x = np.zeros(2*iter+1) #numpy.zeros() - Return a new array of given shape and type, filled with zeros.
    y = np.zeros(2*iter+1)
    x[0] = start
    y[0] = 0
    i = 1
    while i < 2*iter:
        x[i] = x[i-1]
        y[i] = fun(x[i])
        x[i+1] = y[i]
        y[i+1] = y[i]
        i += 2
    u = np.zeros(len(x)-1)
    v = np.zeros(len(y)-1)
    for i in range(len(x)-1):
        u[i] = x[i+1] - x[i]
        v[i] = y[i+1] - y[i]
    return(x, y, u, v)

# %%
# prepare a python function
recF = sp.lambdify(y(t), equ.rhs, "numpy")
display(
    equ,
    inspect.findsource(recF)
    )
# Out:
# p(t + 1) = -0.4⋅p(t)
# (['def _lambdifygenerated(_Dummy_28):\n', '    return (-0.4*_Dummy_28)\n'], 0)

# %%
# Python phase diagram
tval = np.linspace(-5, 5, 50)
x, y, u, v = path(recF, 4, 6)

plt.figure(figsize=(15,15))
plt.plot(tval, recF(tval))
plt.plot(tval, tval, color = 'orange')
plt.plot(tval, recF(tval), color="blue")
plt.vlines(0, -5, 5, color = 'black')
plt.hlines(0, -5, 5, color = 'black')
plt.title("Phase diagram of Cobbweb model")
plt.quiver(x[:-1],y[:-1], u, v,  angles='xy', scale_units='xy', scale=1, width = 0.002, color = 'red')

# %% [markdown]
# # Problem 3 - Solow Model
#
# Central equation of the Solow model:
#
# \begin{equation*}
# \dot{k}(k) = s \cdot a \cdot k^{\alpha} - (n + \delta) \cdot k(t)
# \end{equation*}

# %% [markdown]
# ## c) Plot

# %%
import ipywidgets as widgets #load necessary packages
from ipywidgets import FloatSlider
import sympy.abc as symb
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import figure
from ipywidgets import interact

# %%
s = sp.Symbol('s')
a = sp.Symbol('a')
n = sp.Symbol('n')
alpha = symb.alpha
delta = symb.delta
t = sp.Symbol('t')
k = sp.Function('k')(t)
equa = sp.Eq(k.diff(), s*a*k**alpha-(n+delta)*k)
display(equa)
# Out:
# d               α
# ──(k(t)) = a⋅s⋅k (t) - (δ + n)⋅k(t)
# dt

# %%
equation = sp.lambdify(k, equa.rhs, "numpy")
display(
    equa,
    inspect.findsource(equation)
    )
# Out:
# d               α
# ──(k(t)) = a⋅s⋅k (t) - (δ + n)⋅k(t)
# dt
# (['def _lambdifygenerated(_Dummy_29):\n',
#   '    return (_Dummy_29**alpha*a*s - _Dummy_29*(delta + n))\n'],
#  0)

# %%
def fs(val, min, max, step):
    return FloatSlider(value=val, min=min, max=max, step=step, continuous_update = True)

@interact
def muj_graf(s=fs(0.1,0,1,0.01),a=fs(3,0,5,0.01),alpha=fs(0.3,0,1,0.01),n=fs(0.1,0,1,0.01),delta=fs(0.25,0,1,0.01)):
    t = sp.Symbol('t')
    k = sp.Function('k')(t)
    difr = sp.Eq(k.diff(), s*a*k**alpha-(n+delta)*k)
    difr2 = sp.lambdify(k, difr.rhs, "numpy")
    steady_state = sp.Eq(0, difr.rhs)
    eq_cap =np.array(sp.solve(steady_state,k))
    eq_cap[1]
    print(eq_cap[1])
    display(difr)
    
    max = round(eq_cap[1]*2)
    t_defined = np.linspace(0, max, 500)
    plt.figure(figsize=(5,5))
    plt.plot(t_defined, difr2(t_defined),color="green",label="k'")
    plt.scatter(eq_cap[1],0,label="equilibrium value of k")
    plt.legend()
    plt.vlines(0,-1,1, color = 'black')
    plt.hlines(0,-1,eq_cap[1]*2, color = 'black')
    return plt.figure()
# Out:
# interactive(children=(FloatSlider(value=0.1, description='s', max=1.0, step=0.01), FloatSlider(value=3.0, desc…

# %% [markdown]
# # Problem 4

# %% [markdown]
# ## Qualitative solution and phase diagram

# %%
t = sp.symbols('t', real=True)

x = sp.Function('x')(t)
y = sp.Function('y')(t)

a = sp.symbols('a')
b = sp.symbols('b')
c = sp.symbols('c')
d = sp.symbols('d')
e = sp.symbols('e')
f = sp.symbols('f')
eq1 = sp.Eq(x.diff(t), a*x + b*y + e)
eq2 = sp.Eq(y.diff(t), c*x + d*y + f)
eq1s = eq1.subs([(a,-3),(b,3),(e,2)])
eq2s = eq2.subs([(c,-1),(d,-2),(f,1)])
display(eq1s, eq2s)
# Out:
# d
# ──(x(t)) = -3⋅x(t) + 3⋅y(t) + 2
# dt
# d
# ──(y(t)) = -x(t) - 2⋅y(t) + 1
# dt

# %%
# These are the formulas for equilibrium lines
x0 = sp.solve(sp.Eq(eq1s.rhs), y)[0] #x_dot = 0
y0 = sp.solve(sp.Eq(eq2s.rhs), y)[0] #y_dot = 0

display(x0, y0)
# Out:
# C:\Users\novpe\anaconda3\lib\site-packages\sympy\core\relational.py:495: SymPyDeprecationWarning:
#
# Eq(expr) with rhs default to 0 has been deprecated since SymPy 1.5.
# Use Eq(expr, 0) instead. See
# https://github.com/sympy/sympy/issues/16587 for more info.
#
#   SymPyDeprecationWarning(
# x(t) - 2/3
# 1   x(t)
# ─ - ────
# 2    2

# %%
x_eq = sp.solve(sp.Eq(x0, y0), x)[0]
y_eq = y0.subs(x, x_eq)

display(x_eq, y_eq)
# Out:
# 7/9
# 1/9

# %%
eigens = sp.Matrix([
    sp.Poly(eq1s.rhs).coeffs()[:2],
    sp.Poly(eq2s.rhs).coeffs()[:2]
]).eigenvals()

eigens #just to check if my eigenvalues correspond

sol = sp.dsolve([eq1s, eq2s],[x, y])

# %%
xsize = 25                                        # number of points on x axis
ysize = 25                                        # number of points on y axis
x_vals = np.linspace(-10, 10, xsize)              # prepare the x-values
y_vals = np.linspace(-30, 30, ysize)              # prepare the y-values

xeq = sp.lambdify(x, x0)
yeq = sp.lambdify(x, y0)
x0_vals = [xeq(i) for i in x_vals]                # equilibrium line x' = 0
y0_vals = [yeq(i) for i in x_vals]                # equilibrium line y' = 0

# %%
def particular(eq, x_cond, y_cond, points = 150, tmin = -2, tmax = 2):
  
    xt0 = eq[0].rhs.subs(t,0)                                               # substitute t = 0 into both equations
    yt0 = eq[1].rhs.subs(t,0)
    
    conds = sp.solve([sp.Eq(xt0, x_cond), sp.Eq(yt0, y_cond)])              # find the parameter values
    c1 = sp.Symbol('C1')
    c2 = sp.Symbol('C2')
    
    sol_p = [i.subs([('C1', conds[c1]), ('C2', conds[c2])]) for i in eq]   # and substitute them back into equations

    t_vals = np.linspace(tmin, tmax, points)                                # define t interval
    x_p = np.zeros(points)
    y_p = np.zeros(points)

    xfun = sp.lambdify(t, sol_p[0].rhs)
    yfun = sp.lambdify(t, sol_p[1].rhs)
    
    for i in range(points):                                                  # and calculate x, y values
        x_p[i] = xfun(t_vals[i])
        y_p[i] = yfun(t_vals[i])
    
    return(x_p, y_p)

# %%
xyp = [particular(sol, i[0], i[1]) for i in [(6,10),(-5,-3),(-8,-15),(2.5,2.3)]]
_ = [plt.plot(i[0], i[1], linewidth = 2, color = 'black') for i in xyp]

def vector_field(xfun, yfun, xvals, yvals):
    gridsize = len(xvals) * len(yvals)            # the grid [x,y]
    xa_vals = np.zeros(gridsize)                  # arrow position x
    ya_vals = np.zeros(gridsize)                  # arrow position y
    dxa = np.zeros(gridsize)                      # arrow direction x
    dya = np.zeros(gridsize)                      # arrow direction y
    
    p = 0
    for i in xvals:                               # for every x value
        for j in yvals:                           # for every x & y value
            xa_vals[p] = i                        # save the combination
            ya_vals[p] = j
            dxa[p] = xfun(i, j)                   # calculate both derivatives
            dya[p] = yfun(i, j)
            p += 1                                # increment the position
    
    return(xa_vals, ya_vals, dxa, dya)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-17-0ea37ffed0c0> in <module>
# ----> 1 xyp = [particular(sol, i[0], i[1]) for i in [(6,10),(-5,-3),(-8,-15),(2.5,2.3)]]
#       2 _ = [plt.plot(i[0], i[1], linewidth = 2, color = 'black') for i in xyp]
#       3
#       4 def vector_field(xfun, yfun, xvals, yvals):
#       5     gridsize = len(xvals) * len(yvals)            # the grid [x,y]
#
# <ipython-input-17-0ea37ffed0c0> in <listcomp>(.0)
# ----> 1 xyp = [particular(sol, i[0], i[1]) for i in [(6,10),(-5,-3),(-8,-15),(2.5,2.3)]]
#       2 _ = [plt.plot(i[0], i[1], linewidth = 2, color = 'black') for i in xyp]
#       3
#       4 def vector_field(xfun, yfun, xvals, yvals):
#       5     gridsize = len(xvals) * len(yvals)            # the grid [x,y]
#
# <ipython-input-15-03341e475ffd> in particular(eq, x_cond, y_cond, points, tmin, tmax)
#      14     y_p = np.zeros(points)
#      15
# ---> 16     xfun = sp.lambdify(t, sol_p[0].rhs)
#      17     yfun = sp.lambdify(t, sol_p[1].rhs)
#      18
#
# ~\anaconda3\lib\site-packages\sympy\utilities\lambdify.py in lambdify(args, expr, modules, printer, use_imps, dummify)
#     846     else:
#     847         funcprinter = _EvaluatorPrinter(printer, dummify)
# --> 848     funcstr = funcprinter.doprint(funcname, args, expr)
#     849
#     850     # Collect the module imports from the code printers.
#
# ~\anaconda3\lib\site-packages\sympy\utilities\lambdify.py in doprint(self, funcname, args, expr)
#    1089         funcbody.extend(unpackings)
#    1090
# -> 1091         funcbody.append('return ({})'.format(self._exprrepr(expr)))
#    1092
#    1093         funclines = [funcsig]
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in doprint(self, expr, assign_to)
#     108         self._number_symbols = set()  # type: Set[Tuple[Expr, Float]]
#     109
# --> 110         lines = self._print(expr).splitlines()
#     111
#     112         # format the output
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\str.py in _print_Add(self, expr, order)
#      52         l = []
#      53         for term in terms:
# ---> 54             t = self._print(term)
#      55             if t.startswith('-'):
#      56                 sign = "-"
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in _print_Mul(self, expr)
#     488         a = a or [S.One]
#     489
# --> 490         a_str = [self.parenthesize(x, prec) for x in a]
#     491         b_str = [self.parenthesize(x, prec) for x in b]
#     492
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in <listcomp>(.0)
#     488         a = a or [S.One]
#     489
# --> 490         a_str = [self.parenthesize(x, prec) for x in a]
#     491         b_str = [self.parenthesize(x, prec) for x in b]
#     492
#
# ~\anaconda3\lib\site-packages\sympy\printing\str.py in parenthesize(self, item, level, strict)
#      31     def parenthesize(self, item, level, strict=False):
#      32         if (precedence(item) < level) or ((not strict) and precedence(item) <= level):
# ---> 33             return "(%s)" % self._print(item)
#      34         else:
#      35             return self._print(item)
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\str.py in _print_Add(self, expr, order)
#      52         l = []
#      53         for term in terms:
# ---> 54             t = self._print(term)
#      55             if t.startswith('-'):
#      56                 sign = "-"
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in _print_Mul(self, expr)
#     488         a = a or [S.One]
#     489
# --> 490         a_str = [self.parenthesize(x, prec) for x in a]
#     491         b_str = [self.parenthesize(x, prec) for x in b]
#     492
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in <listcomp>(.0)
#     488         a = a or [S.One]
#     489
# --> 490         a_str = [self.parenthesize(x, prec) for x in a]
#     491         b_str = [self.parenthesize(x, prec) for x in b]
#     492
#
# ~\anaconda3\lib\site-packages\sympy\printing\str.py in parenthesize(self, item, level, strict)
#      31     def parenthesize(self, item, level, strict=False):
#      32         if (precedence(item) < level) or ((not strict) and precedence(item) <= level):
# ---> 33             return "(%s)" % self._print(item)
#      34         else:
#      35             return self._print(item)
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\str.py in _print_Add(self, expr, order)
#      52         l = []
#      53         for term in terms:
# ---> 54             t = self._print(term)
#      55             if t.startswith('-'):
#      56                 sign = "-"
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in _print_Mul(self, expr)
#     488         a = a or [S.One]
#     489
# --> 490         a_str = [self.parenthesize(x, prec) for x in a]
#     491         b_str = [self.parenthesize(x, prec) for x in b]
#     492
#
# ~\anaconda3\lib\site-packages\sympy\printing\codeprinter.py in <listcomp>(.0)
#     488         a = a or [S.One]
#     489
# --> 490         a_str = [self.parenthesize(x, prec) for x in a]
#     491         b_str = [self.parenthesize(x, prec) for x in b]
#     492
#
# ~\anaconda3\lib\site-packages\sympy\printing\str.py in parenthesize(self, item, level, strict)
#      33             return "(%s)" % self._print(item)
#      34         else:
# ---> 35             return self._print(item)
#      36
#      37     def stringify(self, args, sep, level=0):
#
# ~\anaconda3\lib\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\anaconda3\lib\site-packages\sympy\printing\numpy.py in _print_Integral(self, e)
#     437
#     438     def _print_Integral(self, e):
# --> 439         integration_vars, limits = _unpack_integral_limits(e)
#     440
#     441         if len(limits) == 1:
#
# ~\anaconda3\lib\site-packages\sympy\printing\pycode.py in _unpack_integral_limits(integral_expr)
#     535             integration_var, lower_limit, upper_limit = integration_range
#     536         else:
# --> 537             raise NotImplementedError("Only definite integrals are supported")
#     538         integration_vars.append(integration_var)
#     539         limits.append((lower_limit, upper_limit))
#
# NotImplementedError: Only definite integrals are supported

# %%
fig = plt.figure(figsize=(8, 6))
plt.grid()

plt.xlim(-10, 10)
plt.ylim(-30, 30)
plt.xlabel('x')
plt.ylabel('y')

plt.plot(x_vals, x0_vals, linewidth = 4, label = "x'= 0")      # equilibrium lines 
plt.plot(x_vals, y0_vals, linewidth = 4, label = "y'= 0")


plt.legend(bbox_to_anchor=(1.02, 0.55), prop={'size': 15})     # add legend, outside of the plot

_ = [plt.plot(i[0],i[1]) for i in xyp]

# NEW CODE BELLOW:
xfun = sp.lambdify((x,y), eq1s.rhs) 
yfun = sp.lambdify((x,y), eq2s.rhs)

xa, ya, dxa, dya = vector_field(xfun, yfun, x_vals, y_vals)
plt.quiver(xa, ya, dxa, dya)                                   # add the arrows

# %% [markdown]
# # MMM - Problem Set 3 #
# ## IES FSV UK		##
# Notes:
# Homework is due to 6th December 23:59. Upload files via Moodle. If you face any problem with uploading files, send the files via email to josef.strasky@gmail.com and michal.kubista@nielsen.com

# %% [markdown]
# # 1) Consider the simplified IS-LM model specified in the IS-LM_lecture #

# %% [markdown]
# Following code is obtained from seminars and serves the purpose of obtaining the phase diagram

# %%
#loading necessary packages
import sympy as sp
import sympy.abc as sbc
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import FloatSlider

sp.init_printing()

# %%
def particular(eq, x_cond, y_cond, points = 150, tmin = -2, tmax = 2): # to calculate the particular solutions
    xt0 = eq[0].rhs.subs(t, 0)                                               # substitute t = 0 into both equations
    yt0 = eq[1].rhs.subs(t, 0)
    
    conds = sp.solve([sp.Eq(xt0, x_cond), sp.Eq(yt0, y_cond)])               # find the parameter values
    c1 = sp.Symbol('C1')
    c2 = sp.Symbol('C2')
    
    sol_p = [i.subs([(c1, conds[c1]), (c2, conds[c2])]) for i in eq]         # and substitute them back into equations

    t_vals = np.linspace(tmin, tmax, points)                                 # define t interval
    x_p = np.zeros(points)
    y_p = np.zeros(points)

    xfun = sp.lambdify(t, sol_p[0].rhs)
    yfun = sp.lambdify(t, sol_p[1].rhs)
    
    for i in range(points):                                                  # and calculate x, y values
        x_p[i] = xfun(t_vals[i])
        y_p[i] = yfun(t_vals[i])
    
    return(x_p, y_p)

# %%
def vector_field(xfun, yfun, xvals, yvals):                                 # to calculate data from the vector field
    gridsize = len(xvals) * len(yvals)            # the grid [x,y]
    xa_vals = np.zeros(gridsize)                  # arrow positions x, y
    ya_vals = np.zeros(gridsize)
    dxa = np.zeros(gridsize)                      # arrow directions x, y
    dya = np.zeros(gridsize)
    
    p = 0
    for i in xvals:                               # for every x value
        for j in yvals:                           # for every y value
            xa_vals[p] = i                        # save the combination
            ya_vals[p] = j
            dxa[p] = xfun(i, j)                   # calculate both derivatives
            dya[p] = yfun(i, j)
            p += 1                                # increment the position
    
    return(xa_vals, ya_vals, dxa, dya)

# %%
# defining variables and functions to create the needed setup later on
t = sp.symbols('t', real=True)
y = sp.Function('y')(t)
r = sp.Function('r')(t)
e = sp.Function('e')(t)
md = sp.Function('md')(t)

alpha = sbc.alpha
beta = sbc.beta

a = sp.symbols('a')
b = sp.symbols('b')
h = sp.symbols('h')
k = sp.symbols('k')
m0 = sp.symbols('m0')
T = sp.symbols('T')
u = sp.symbols('u')
c1 = sp.symbols('C1')
c2 = sp.symbols('C2')
exp = sp.Eq(e, a + b*(1 - T)*y - h*r) # creating the setup
mdem = sp.Eq(md, k*y - u*r)

# %%
display(exp, mdem)
adj_g = sp.Eq(y.diff(), alpha*(e - y))   # again, creating setup
adj_m = sp.Eq(r.diff(), beta*(md - m0))

display(adj_g, adj_m)
yt = adj_g.subs(e, exp.rhs)      # combining the equations above using substitution
rt = adj_m.subs(md, mdem.rhs)
# Out:
# e(t) = a + b⋅(1 - T)⋅y(t) - h⋅r(t)
# md(t) = k⋅y(t) - u⋅r(t)
# d
# ──(y(t)) = α⋅(e(t) - y(t))
# dt
# d
# ──(r(t)) = β⋅(-m₀ + md(t))
# dt

# %%
display(yt, rt)
IS = sp.solve(yt.subs(y.diff(), 0), r)[0]     # we get the expressions for equilibrium lines by putting the equations above equal to 0
LM = sp.solve(rt.subs(r.diff(), 0), r)[0]

display(sp.Eq(r, IS), sp.Eq(r, LM))
# Out:
# d
# ──(y(t)) = α⋅(a + b⋅(1 - T)⋅y(t) - h⋅r(t) - y(t))
# dt
# d
# ──(r(t)) = β⋅(k⋅y(t) - m₀ - u⋅r(t))
# dt
#        -T⋅b⋅y(t) + a + b⋅y(t) - y(t)
# r(t) = ─────────────────────────────
#                      h
#        k⋅y(t) - m₀
# r(t) = ───────────
#             u

# %%
IS_param = [(alpha, 3), (T, 0.3), (b, 0.6), (a, 5), (h, 1)]   # specifing the IS/LM parameters (just copied from seminar)
LM_param = [(beta, 2), (k, 3), (m0, 3), (u, 2.5)]

# %%
IS_s = IS.subs(IS_param)             # now substituing the parameters for the equilibrium lines
LM_s = LM.subs(LM_param)

display(sp.Eq(r, IS_s), sp.Eq(r, LM_s))
# Out:
# r(t) = 5 - 0.58⋅y(t)
# r(t) = 1.2⋅y(t) - 1.2

# %%
y_eq = sp.solve(sp.Eq(LM_s, IS_s), y)[0]   # solving the system of two equations from above to get the value of y(t)&r(t), this is where the IS  and LM lines intersect
r_eq = IS_s.subs(y, y_eq)

display(sp.Eq(y,y_eq), sp.Eq(r, r_eq))
# Out:
# y(t) = 3.48314606741573
# r(t) = 2.97977528089888

# %%
lower = -10                     
upper = 20

y_vals = np.linspace(lower, upper)                      # defining y-values on the interval

rval_IS = [float(IS_s.subs(y, i)) for i in y_vals]      # plugging the in specific values from above to get the r-values
rval_LM = [float(LM_s.subs(y, i)) for i in y_vals]

# %%
yt_s = yt.rhs.subs(IS_param)                            # substituing the parameters into the yt & rt 
rt_s = rt.rhs.subs(LM_param)

rspace = np.linspace(lower, upper, 15)
yspace = np.linspace(lower, upper, 15)

yfun = sp.lambdify((y, r), yt_s)                        # making python functions that will evalute the yt_s & rt_s, with y & r parameters
rfun = sp.lambdify((y, r), rt_s)

y_a, r_a, y_ad, r_ad = vector_field(yfun, rfun, yspace, rspace) # preparing data for vector field using the vector_field function on the two function defined above and the "axis range"

# %%
eigen = sp.Matrix([
    sp.Poly(rt_s).coeffs()[:-1],
    sp.Poly(yt_s).coeffs()[:-1]
]).eigenvects()

eigen_vals = y_vals * (-1) * sp.re(eigen[0][2][0][0].evalf()) + r_eq

eigen
# Out:
# ⎡⎛                               ⎡⎡-0.313693646259697 - 0.753832184881332⋅ⅈ⎤⎤⎞
# ⎢⎜-3.37 - 3.91702693378537⋅ⅈ, 1, ⎢⎢                                        ⎥⎥⎟
# ⎣⎝                               ⎣⎣           -0.577350269189626           ⎦⎦⎠
#
#   ⎛                               ⎡⎡ 0.866025403784439 + 0.360380827610103⋅ⅈ ⎤
# , ⎜-3.37 + 3.91702693378537⋅ⅈ, 1, ⎢⎢                                         ⎥
#   ⎝                               ⎣⎣-6.0649167869453e-66 + 0.66327759682841⋅ⅈ⎦
#
# ⎤⎞⎤
# ⎥⎟⎥
# ⎦⎠⎦

# %%
sol = sp.dsolve(                                                # solving the equations for y&r
    [sp.Eq(y.diff(), yt_s), sp.Eq(r.diff(), rt_s)],
    [y, r]
)
sol
# Out:
# ⎡                                                                       -3.37⋅
# ⎣y(t) = (-3⋅C₁⋅cos(3.91702693378537⋅t) - 3⋅C₂⋅sin(3.91702693378537⋅t))⋅ℯ
#
# t
#   + 3.48314606741573, r(t) = (C₁⋅(-3.91702693378537⋅sin(3.91702693378537⋅t) -
#
#
# 1.63⋅cos(3.91702693378537⋅t)) + C₂⋅(-1.63⋅sin(3.91702693378537⋅t) + 3.91702693
#
#                                   -3.37⋅t                   ⎤
# 378537⋅cos(3.91702693378537⋅t)))⋅ℯ        + 2.97977528089888⎦

# %%
fig = plt.figure(figsize = (10, 8))                                   # bigger plot

plt.xlabel('y')
plt.ylabel('r')
plt.xlim(lower, upper)
plt.ylim(lower, upper)
plt.grid()

plt.plot(y_vals, rval_IS, linewidth = 4, label = "IS")               
plt.plot(y_vals, rval_LM, linewidth = 4, label = "LM")

plt.plot(y_vals + y_eq, eigen_vals, label = "eig")

plt.legend(bbox_to_anchor=(1.30, 0.55), prop={'size': 15})             # add legend, outside of the plot

plt.hlines(0, xmin = lower, xmax = upper, color = 'black')             # strengthen the x axis
plt.vlines(0, ymin = lower, ymax = upper, color = 'black')             # strengthen the y axis

plt.quiver(y_a, r_a, y_ad, r_ad)                                       # arrows

x0p, y0p = particular(sol, 10, 0)                                      # 2 particular solutions
plt.plot(x0p, y0p, linewidth = 2)

x1p, y1p = particular(sol, 2, 0)
plt.plot(x1p, y1p, linewidth = 2)

plt.show()

# %% [markdown]
# ### a)	Comment extensively all features of the plot (all lines, arrows, curves ,...). From the comments it must be obvious that you understand the IS-LM model and how the model is illustrated using the phase diagram.

# %% [markdown]
# - IS line (blue)
#     - stands for "I"nvestment-"S"avings, the relationships of whose this line represents
#     - the theory states that when interest rate decrease, people are disincentivised to delay consumption (ie save)
#       when the reward for this behavior is lower that it was. The increase in consumption pushes the demand in the
#       goods market up, increasing incomes.
# - LM line (orange)
#     - stands for "L"iquidity-"M"oney Supply
#     - the theory states that in during economic expansion, financial institutions need money to expand, so there is rise in demand for money. They therefore encourage people to save more through high interest rates.
#
# The IS and LM lines meet in an equilibrium.
#
# - real path of eigenvectors (green)
#
# - black arrows
#     - direction of the arrows is given by up/down direction of LM line and left/right direction of IS line
#     - we can see that the

# %% [markdown]
# The arrows present in the phase diagram are the product of two sets of arrows - one of each of the equilibirium lines. For the IS line, when we are above, the arrows go to the left, and when we are below the line, the arrows go to the right. For the LM line, when we are below, the arrows go up, and when we are above, the arrows go down. Therefore, when we combine the sets of arrow in each quadrant, we get the "circle" direction as can be seen in the graph above (it is moving towards both lines). The solution of this system will then converge to the equilibrium (intersection of the lines).

# %% [markdown]
# The red and purple curves are the particular solutions (with specified initial conditions) and they of course go towards the equilibrium (as they follow the direction of the arrows).

# %% [markdown]
# ### b)	Comment briefly (but precisely) how the plot develops with change in ‘a’ parameter. Describe very briefly the economic meaning of ‘a’ parameter, meaning of its change and economic implications.

# %% [markdown]
# The parameter "a" stands for autonomous (government) expenditure and it shifts the IS curve as it is present in the expenditure function. When "a" goes up (expansive fiscal policy), the IS curve is shifted upwards and vice versa (restrictive fiscal policy => down).

# %% [markdown]
# ### c) Describe (briefly but precisely) values of the parameters of the model to get ###
# #### a)	‘liquidity trap’
# Liquidity trap occurs when parameter "k" (which is linked to real income) is zero (LM is a horizontal line). Also, we have to consider that we cannot have negative interest rates, therefore the intersection of the LM line with y-axis cannot be below zero. That means that -m0/u has to be positive -> "u" must be negative (we cannot have negative money supply m0). There is no change in interest rate with change in output.
# #### b)	‘crowding out’
# Crowding out occurs when parameter "u" (which is linked to real interest rate) is very close to zero (LM is a vertical line). This means that the slope of of LM line is such that it never intersects the y-axis. There is no change in output with change in interest rate.

# %% [markdown]
# ### d) Illustrate these situations using the phase diagram in Python (send with proper values of parameters to illustrate each of these situations).

# %% [markdown]
# ### interactive graph for liquidity trap

# %%
ISfun = sp.lambdify((a, b, h, T, y), IS)
LMfun = sp.lambdify((k, m0, u, y), LM)

# define the update function
def update(a_v = 3, alpha_v = 0.50, b_v = 0.30, beta_v = 0.60, h_v = 0.3, k_v = 0, m0_v = 2, T_v = 0.1, u_v = -1):
    
    # LINE VALUES
    rval_y = [ISfun(a_v, b_v, h_v, T_v, i) for i in y_vals]
    rval_r = [LMfun(k_v, m0_v, u_v, i) for i in y_vals]
    
    # SUBSTITUTE & SOLVE particular solution
    y_s = yt.subs([(a, a_v), (alpha, alpha_v), (b, b_v), (h, h_v), (T, T_v)])
    r_s = rt.subs([(beta, beta_v), (k, k_v), (m0, m0_v), (u, u_v)])
    
    y_func = sp.Function('y')(t) 
    r_func = sp.Function('r')(t)
    sol = sp.dsolve([y_s, r_s], [y_func, r_func])
    
    y_partic, r_partic = particular(sol, 10, 4, 5000, -50, 100)
    
    # PREPARE GRID & VECTORFIELD
    rspace = np.linspace(lower, upper, 15)
    yspace = np.linspace(lower, upper, 15)

    yfun = sp.lambdify((y, r), y_s.rhs)
    rfun = sp.lambdify((y, r), r_s.rhs)

    y_a, r_a, y_ad, r_ad = vector_field(yfun, rfun, yspace, rspace)
    
    # PLOT
    fig = plt.figure(figsize=(10, 8))

    plt.xlabel('y')
    plt.ylabel('r')
    plt.xlim(lower, upper)
    plt.ylim(lower, upper)
    plt.grid()

    plt.plot(y_vals, rval_y, linewidth = 4, label = "IS")               
    plt.plot(y_vals, rval_r, linewidth = 4, label = "LM")
    plt.legend(bbox_to_anchor = (1.30, 0.55), prop = {'size': 15})

    plt.hlines(0, xmin = lower, xmax = upper, color = 'black')
    plt.vlines(0, ymin = lower, ymax = upper, color = 'black')

    plt.plot(y_partic, r_partic)
    plt.quiver(y_a, r_a, y_ad, r_ad, width = 0.002)
    plt.show()

# %%
def fs(val, min, max, step):
    return FloatSlider(value=val, min=min, max=max, step=step, continuous_update = False)

# %%
widgets.interact(update,
                a_v =     fs(3, 0, 5, 0.10),
                alpha_v = fs(0.5, 0.10, 5, 0.10) ,
                b_v =     fs(0.3, 0.01, 1, 0.01),
                beta_v =  fs(0.6, 0.01, 1, 0.01),
                h_v =     fs(0.3, 0.01, 5, 0.10),
                m0_v =    fs(2, 0, 5, 0.10),
                T_v =     fs(0.1, 0.01, 1, 0.01), 
                u_v =     fs(-1, -5, 0, 0.1))
# Out:
# interactive(children=(FloatSlider(value=3.0, continuous_update=False, description='a_v', max=5.0), FloatSlider…
# <function __main__.update(a_v=3, alpha_v=0.5, b_v=0.3, beta_v=0.6, h_v=0.3, k_v=0, m0_v=2, T_v=0.1, u_v=-1)>

# %% [markdown]
# ### interactive graph for crowding out

# %%
ISfun = sp.lambdify((a, b, h, T, y), IS)
LMfun = sp.lambdify((k, m0, u, y), LM)

# define the update function
def update(a_v = 3, alpha_v = 0.50, b_v = 0.30, beta_v = 0.60, h_v = 0.3, k_v = 2, m0_v = 2, T_v = 0.1, u_v = 0.001):
    
    # LINE VALUES
    rval_y = [ISfun(a_v, b_v, h_v, T_v, i) for i in y_vals]
    rval_r = [LMfun(k_v, m0_v, u_v, i) for i in y_vals]
    
    # SUBSTITUTE & SOLVE particular solution
    y_s = yt.subs([(a, a_v), (alpha, alpha_v), (b, b_v), (h, h_v), (T, T_v)])
    r_s = rt.subs([(beta, beta_v), (k, k_v), (m0, m0_v), (u, u_v)])
    
    y_func = sp.Function('y')(t) 
    r_func = sp.Function('r')(t)
    sol = sp.dsolve([y_s, r_s], [y_func, r_func])
    
    y_partic, r_partic = particular(sol, 10, 4, 5000, -50, 100)
    
    # PREPARE GRID & VECTORFIELD
    rspace = np.linspace(lower, upper, 15)
    yspace = np.linspace(lower, upper, 15)

    yfun = sp.lambdify((y, r), y_s.rhs)
    rfun = sp.lambdify((y, r), r_s.rhs)

    y_a, r_a, y_ad, r_ad = vector_field(yfun, rfun, yspace, rspace)
    
    # PLOT
    fig = plt.figure(figsize=(10, 8))

    plt.xlabel('y')
    plt.ylabel('r')
    plt.xlim(lower, upper)
    plt.ylim(lower, upper)
    plt.grid()

    plt.plot(y_vals, rval_y, linewidth = 4, label = "IS")               
    plt.plot(y_vals, rval_r, linewidth = 4, label = "LM")
    plt.legend(bbox_to_anchor = (1.30, 0.55), prop = {'size': 15})

    plt.hlines(0, xmin = lower, xmax = upper, color = 'black')
    plt.vlines(0, ymin = lower, ymax = upper, color = 'black')

    plt.plot(y_partic, r_partic)
    plt.quiver(y_a, r_a, y_ad, r_ad, width = 0.002)
    plt.show()

# %%
def fs(val, min, max, step):
    return FloatSlider(value=val, min=min, max=max, step=step, continuous_update = False)

# %%
widgets.interact(update,
                a_v =     fs(3, 0, 5, 0.10),
                alpha_v = fs(0.5, 0.10, 5, 0.10) ,
                b_v =     fs(0.3, 0.01, 1, 0.01),
                beta_v =  fs(0.6, 0.01, 1, 0.01),
                h_v =     fs(0.3, 0.01, 5, 0.10),
                k_v =     fs(2, 0, 5, 0.10),
                m0_v =    fs(2, 0, 5, 0.10),
                T_v =     fs(0.1, 0.01, 1, 0.01), 
                u_v =     fs(0.001, 0, 1, 0.001))
# Out:
# interactive(children=(FloatSlider(value=3.0, continuous_update=False, description='a_v', max=5.0), FloatSlider…
# <function __main__.update(a_v=3, alpha_v=0.5, b_v=0.3, beta_v=0.6, h_v=0.3, k_v=2, m0_v=2, T_v=0.1, u_v=0.001)>

# %% [markdown]
# ### e)

# %% [markdown]
# #### Liquidity trap:
# Expansionary <b>fiscal policy</b> is effective since it helps to offset the increase in private sector saving and injects money into the circular flow. Fiscal policy "influences" the IS curve, therefore this logic can also be seen in the graph: when IS is shifted upwards (e.g. increase in governemnt spending), y inreases; when the slope of IS changes (e.g. T decreases), y increases.
#
# <b>Monetary policy</b> is ineffective because the interest rate is nearly zero => the opportunity cost of holding money becomes nil and even when the Central Bank increases the money supply to stimulate the economy, the economic agents will continue to accumulate money instead of investing it.

# %% [markdown]
# #### Crowding out:

# %% [markdown]
# <b>Fiscal policy</b> in this case does not have effect on y, only on interest rates (since the LM curve is vertical). Therefore, it is ineffective.

# %% [markdown]
# # Problem 2

# %%
from ipywidgets import IntProgress

import random as rd

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Bellman equation:
# $V(k_t)=\underset{k_{t+1}}{\operatorname{max}}(u(f(k_t)-k_{t+1})+\beta V(k_{t+1}))$
#
# Iterations:
# $V_{j+1}(k_t) = \underset{k_{t+1}}{\operatorname{max}}(u(f(k_t) - k_{t+1}) + \beta V_j(k_{t+1}))$

# %% [markdown]
# ## a) & b)

# %%
#A is tech. growth
#alpha is cobb-goudlas parameter
#beta is discount factor
#kspace is definition of the interval on which we define the function
def bellmanRam(A, alpha, beta, kspace, iters = 200, toler = 1e-6):
    ksize = len(kspace) #iters is the max number of iterations; toler is the convergence parameter
                        
    V_old = np.zeros(ksize) #vector of zeros (value mapping), it is the initial guess
    V_new = np.zeros([ksize, ksize]) # calculated below, originally matix of 0s
    
    for e in range(iters):
        diff = 0                           # original difference
        for j in range(ksize):             # over k_t
            kt = kspace[j]
            for i in range(ksize):         # over k_t1
                kt1 = kspace[i]
                V_new[j,i] = np.log(A*kt**alpha - kt1) + beta*V_old[i] # matrix with all values from this computation

            V_max, posmax = (np.nanmax(V_new, axis = 1),   # position of the maximum utility & the estimate
                             np.argmax(V_new, axis = 1))
            diff += abs(V_max[j] - V_old[j])               # how is it different from the old one 

        if diff <= toler:                                  # if the differemce is smaller than tolerance, then we have convergence
            break
        else:                                              # otherwise, we rewrite the old function and save the optimal consumption and run it again
            V_old = V_max
            kopt = kspace[posmax]
    
    return(kspace, kopt)                                  # the function gives us the optimal k and the interval

# %%
kspace, kopt = bellmanRam(A = 12, alpha = 0.30, beta = 0.90, kspace = np.arange(2, 10, 0.05))
#now I apply it for the given numbers and interval

# %% [markdown]
# ## c)

# %%
#now we plot
fig = plt.figure(figsize=(16, 12))
plt.title('Equilibrium at k* ~ ' + str(kspace[kopt == kspace].mean())) #this will print the equilibrium (optimal choices for k from the iterations&45°line intersection)
plt.plot(kspace, kopt)
plt.plot(kspace, kspace)
_ = plt.ylim(2,10)
_ = plt.vlines(kspace[kopt == kspace].mean(), 2, 10, linestyles = 'dashed', color = 'black') # intercept vertical line

# %% [markdown]
# We can use this plot to find the equlibrium since it shows the intersection of the 45° line and the optimal choices for $k$ (as calculated by the iterations).

# %% [markdown]
# ## d)

# %% [markdown]
# The equilibrium is already calculated in the graph. However, we can get a more precise estimate by decreasing the last value in the kspace specification.

# %%
str(kspace[kopt == kspace].mean())       #the original
# Out:
# '5.349999999999988'

# %%
kspace, kopt = bellmanRam(A = 12, alpha = 0.30, beta = 0.90, kspace = np.arange(2, 10, 0.03))                 # decreased to 0.03

# %%
str(kspace[kopt == kspace].mean())     #printing the value
# Out:
# '5.359999999999978'

# %%
kspace, kopt = bellmanRam(A = 12, alpha = 0.30, beta = 0.90, kspace = np.arange(2, 10, 0.02))

# %%
str(kspace[kopt == kspace].mean())
# Out:
# '5.360000000000003'

# %%
kspace, kopt = bellmanRam(A = 12, alpha = 0.30, beta = 0.90, kspace = np.arange(2, 10, 0.01))  #this is my last "decrease" since this one already took pretty long to process

# %%
str(kspace[kopt == kspace].mean())
# Out:
# '5.359999999999928'

# %% [markdown]
# I conclude that the equilibirum k* is 5.359999999999928 (as this is what I got with the "densiest" mesh).
